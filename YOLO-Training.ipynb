# %%
from ultralytics import YOLO
import cv2 as cv
import torch

# %%
print(torch.cuda.is_available())  # Should return True if CUDA is available
print(torch.cuda.get_device_name(0))  # Prints the name of your GPU

# %%
# Load model
model = YOLO('yolo11l.pt')

# %%
# # Tune hyperparameters
# model.tune(
#     data='C:/Users/Trever/Desktop/Dataset/Final/Versions/v1/data.yaml',
#     epochs=50,
#     iterations=100,
#     device=0,
#     optimizer="AdamW",
#     save=True,
#     plots=True,
#     val=True
# )

# %%
trainResults = model.train(
    data='C:/Users/Trever/Desktop/Dataset/Final/Versions/v7 Augmented Single Class/data.yaml',
    epochs=50,
    imgsz=640,
    augment=False,
    device=0,
    seed=42,
    batch=-1,
    single_cls=True
)
